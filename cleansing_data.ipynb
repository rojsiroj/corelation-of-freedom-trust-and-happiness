# %%
import pandas as pd

# %%
df2015 = pd.read_csv('dataset/2015.csv')
df2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df2015 = df2015.drop(df2015.columns[[1, 4, 6, 10, 11]], axis=1)
df2015
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
# ...

# %%
df2015 = df2015.rename(columns={'Country': 'country', 'Happiness Rank': 'happiness_rank', 'Happiness Score': 'happiness_score', 'Health (Life Expectancy)': 'life_expextancy', 'Economy (GDP per Capita)': 'economy_gdp', 'Freedom': 'freedom', 'Trust (Government Corruption)': 'trust_goverment'})
df2015
# Out:
#          country  happiness_rank  happiness_score  economy_gdp  \
# 0    Switzerland               1            7.587      1.39651
# 1        Iceland               2            7.561      1.30232
# 2        Denmark               3            7.527      1.32548
# 3         Norway               4            7.522      1.45900
# 4         Canada               5            7.427      1.32629
# ..           ...             ...              ...          ...
# 153       Rwanda             154            3.465      0.22208
# 154        Benin             155            3.340      0.28665
# 155        Syria             156            3.006      0.66320
# 156      Burundi             157            2.905      0.01530
# 157         Togo             158            2.839      0.20868
#
#      life_expextancy  freedom  trust_goverment
# 0            0.94143  0.66557          0.41978
# 1            0.94784  0.62877          0.14145
# 2            0.87464  0.64938          0.48357
# ...

# %%
df2016 = pd.read_csv('dataset/2016.csv')
df2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df2016 = df2016.drop(df2016.columns[[1, 4, 5, 7, 11, 12]], axis=1)
df2016
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        Denmark               1            7.526                   1.44178
# 1    Switzerland               2            7.509                   1.52733
# 2        Iceland               3            7.501                   1.42666
# 3         Norway               4            7.498                   1.57744
# 4        Finland               5            7.413                   1.40598
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
# ...

# %%
df2016 = df2016.rename(columns={'Country': 'country', 'Happiness Rank': 'happiness_rank', 'Happiness Score': 'happiness_score', 'Health (Life Expectancy)': 'life_expextancy', 'Economy (GDP per Capita)': 'economy_gdp', 'Freedom': 'freedom', 'Trust (Government Corruption)': 'trust_goverment'})
df2016
# Out:
#          country  happiness_rank  happiness_score  economy_gdp  \
# 0        Denmark               1            7.526      1.44178
# 1    Switzerland               2            7.509      1.52733
# 2        Iceland               3            7.501      1.42666
# 3         Norway               4            7.498      1.57744
# 4        Finland               5            7.413      1.40598
# ..           ...             ...              ...          ...
# 152        Benin             153            3.484      0.39499
# 153  Afghanistan             154            3.360      0.38227
# 154         Togo             155            3.303      0.28123
# 155        Syria             156            3.069      0.74719
# 156      Burundi             157            2.905      0.06831
#
#      life_expextancy  freedom  trust_goverment
# 0            0.79504  0.57941          0.44453
# 1            0.86303  0.58557          0.41203
# 2            0.86733  0.56624          0.14975
# ...

# %%
df2017 = pd.read_csv('dataset/2017.csv')
df2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df2017 = df2017.drop(df2017.columns[[3, 4, 6, 9, 11]], axis=1)
df2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy..GDP.per.Capita.  Health..Life.Expectancy.   Freedom  \
# 0                    1.616463                  0.796667  0.635423
# 1                    1.482383                  0.792566  0.626007
# ...

# %%
df2017 = df2017.rename(columns={'Country': 'country', 'Happiness.Rank': 'happiness_rank', 'Happiness.Score': 'happiness_score', 'Health..Life.Expectancy.': 'life_expextancy', 'Economy..GDP.per.Capita.': 'economy_gdp', 'Freedom': 'freedom', 'Trust..Government.Corruption.': 'trust_goverment'})
df2017
# Out:
#                       country  happiness_rank  happiness_score  economy_gdp  \
# 0                      Norway               1            7.537     1.616463
# 1                     Denmark               2            7.522     1.482383
# 2                     Iceland               3            7.504     1.480633
# 3                 Switzerland               4            7.494     1.564980
# 4                     Finland               5            7.469     1.443572
# ..                        ...             ...              ...          ...
# 150                    Rwanda             151            3.471     0.368746
# 151                     Syria             152            3.462     0.777153
# 152                  Tanzania             153            3.349     0.511136
# 153                   Burundi             154            2.905     0.091623
# 154  Central African Republic             155            2.693     0.000000
#
#      life_expextancy   freedom  trust_goverment
# ...

# %%
df2018 = pd.read_csv('dataset/2018.csv')
df2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df2018 = df2018.drop(df2018.columns[[4,7]], axis=1)
df2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Healthy life expectancy  Freedom to make life choices  \
# 0                      0.874                         0.681
# ...

# %%
df2018 = df2018.rename(columns={'Country or region': 'country', 'Overall rank': 'happiness_rank', 'Score': 'happiness_score', 'Healthy life expectancy': 'life_expextancy', 'GDP per capita': 'economy_gdp', 'Freedom to make life choices': 'freedom', 'Perceptions of corruption': 'trust_goverment'})
df2018
# Out:
#      happiness_rank                   country  happiness_score  economy_gdp  \
# 0                 1                   Finland            7.632        1.305
# 1                 2                    Norway            7.594        1.456
# 2                 3                   Denmark            7.555        1.351
# 3                 4                   Iceland            7.495        1.343
# 4                 5               Switzerland            7.487        1.420
# ..              ...                       ...              ...          ...
# 151             152                     Yemen            3.355        0.442
# 152             153                  Tanzania            3.303        0.455
# 153             154               South Sudan            3.254        0.337
# 154             155  Central African Republic            3.083        0.024
# 155             156                   Burundi            2.905        0.091
#
#      life_expextancy  freedom  trust_goverment
# ...

# %%
df2019 = pd.read_csv('dataset/2019.csv')
df2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df2019 = df2019.drop(df2019.columns[[4,7]], axis=1)
df2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Healthy life expectancy  Freedom to make life choices  \
# 0                      0.986                         0.596
# ...

# %%
df2019 = df2019.rename(columns={'Country or region': 'country', 'Overall rank': 'happiness_rank', 'Score': 'happiness_score', 'Healthy life expectancy': 'life_expextancy', 'GDP per capita': 'economy_gdp', 'Freedom to make life choices': 'freedom', 'Perceptions of corruption': 'trust_goverment'})
df2019
# Out:
#      happiness_rank                   country  happiness_score  economy_gdp  \
# 0                 1                   Finland            7.769        1.340
# 1                 2                   Denmark            7.600        1.383
# 2                 3                    Norway            7.554        1.488
# 3                 4                   Iceland            7.494        1.380
# 4                 5               Netherlands            7.488        1.396
# ..              ...                       ...              ...          ...
# 151             152                    Rwanda            3.334        0.359
# 152             153                  Tanzania            3.231        0.476
# 153             154               Afghanistan            3.203        0.350
# 154             155  Central African Republic            3.083        0.026
# 155             156               South Sudan            2.853        0.306
#
#      life_expextancy  freedom  trust_goverment
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Top 10 Most Happiness Country in 2019')
df = df2019.head(10)
plt.plot(df['country'], df['happiness_score'], label='Happiness Score')
plt.bar(df['country'], df['freedom'], label='Freedom')
plt.xlabel("Country")
plt.ylabel("Happiness Score")
plt.show()

# %%
plt.title('Freedom = Happiness? in 2019')
plt.scatter(df2019['freedom'], df2019['happiness_score'])
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.show()


plt.title('Freedom = Happiness? in 2018')
plt.scatter(df2018['freedom'], df2018['happiness_score'])
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.show()


plt.title('Freedom = Happiness? in 2017')
plt.scatter(df2017['freedom'], df2017['happiness_score'])
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.show()

plt.title('Freedom = Happiness? in 2016')
plt.scatter(df2016['freedom'], df2016['happiness_score'])
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.show()

plt.title('Freedom = Happiness? in 2015')
plt.scatter(df2015['freedom'], df2015['happiness_score'])
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.show()

# %%
plt.title('Freedom = High GDP? in 2019')
plt.scatter(df2019['freedom'], df2019['economy_gdp'])
plt.xlabel("Freedom")
plt.ylabel("GDP")
plt.show()


plt.title('Freedom = High GDP? in 2018')
plt.scatter(df2018['freedom'], df2018['economy_gdp'])
plt.xlabel("Freedom")
plt.ylabel("GDP")
plt.show()


plt.title('Freedom = High GDP? in 2017')
plt.scatter(df2017['freedom'], df2017['economy_gdp'])
plt.xlabel("Freedom")
plt.ylabel("GDP")
plt.show()

plt.title('Freedom = High GDP? in 2016')
plt.scatter(df2016['freedom'], df2016['economy_gdp'])
plt.xlabel("Freedom")
plt.ylabel("GDP")
plt.show()

plt.title('Freedom = High GDP? in 2015')
plt.scatter(df2015['freedom'], df2015['economy_gdp'])
plt.xlabel("Freedom")
plt.ylabel("GDP")
plt.show()
