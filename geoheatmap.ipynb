# %% [markdown]
# # Step #1 Load the Data

# %%
import sys
# !{sys.executable} -m pip install country_converter --upgrade
# !{sys.executable} -m pip install geopandas --upgrade
# Out:
# Requirement already satisfied: country_converter in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (0.7.7)
# Requirement already satisfied: pandas>=1.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from country_converter) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->country_converter) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->country_converter) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Requirement already satisfied: geopandas in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: pandas>=1.0.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: shapely<2,>=1.7 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: fiona>=1.8 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.22)
# Requirement already satisfied: packaging in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.4.0)
# Requirement already satisfied: six>=1.7 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: certifi in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2022.5.18.1)
# Requirement already satisfied: cligj>=0.5 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: attrs>=17 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: munch in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/rojsiroj/opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)

# %%
# A tutorial for this file is available at www.relataly.com

# Setting up Packages
import json
import country_converter as coco
from datetime import datetime, timedelta
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# Getting the data
PAYLOAD = {'code': 'ALL'}
URL = 'https://api.statworx.com/covid'
RESPONSE = requests.post(url=URL, data=json.dumps(PAYLOAD))

# Convert the response to a data frame
covid_df = pd.DataFrame.from_dict(json.loads(RESPONSE.text))
covid_df.head(3)
# Out:
#          date day month  year  cases  deaths      country code  population  \
# 0  2019-12-31  31    12  2019      0       0  Afghanistan   AF  38041757.0
# 1  2020-01-01  01    01  2020      0       0  Afghanistan   AF  38041757.0
# 2  2020-01-02  02    01  2020      0       0  Afghanistan   AF  38041757.0
#
#   continent  cases_cum  deaths_cum
# 0      Asia          0           0
# 1      Asia          0           0
# 2      Asia          0           0

# %%
# Setting the path to the shapefile
SHAPEFILE = 'shapefiles/ne_10m_admin_0_countries.shp'

# Read shapefile using Geopandas
geo_df = gpd.read_file(SHAPEFILE)[['ADMIN', 'ADM0_A3', 'geometry']]

# Rename columns.
geo_df.columns = ['country', 'country_code', 'geometry']
geo_df.head(3)
# Out:
#      country country_code                                           geometry
# 0  Indonesia          IDN  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1   Malaysia          MYS  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2      Chile          CHL  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...

# %% [markdown]
# # Step #2 Preprocessing the Data

# %%
# Drop row for 'Antarctica'. It takes a lot of space in the map and is not of much use
geo_df = geo_df.drop(geo_df.loc[geo_df['country'] == 'Antarctica'].index)

# Print the map
geo_df.plot(figsize=(20, 20), edgecolor='white', linewidth=1, color='lightblue')
# Out:
# <AxesSubplot:>

# %%
# Next, we need to ensure that our data matches with the country codes. 
iso3_codes = geo_df['country'].to_list()

# Convert to iso3_codes
iso2_codes_list = coco.convert(names=iso3_codes, to='ISO2', not_found='NULL')

# Add the list with iso2 codes to the dataframe
geo_df['iso2_code'] = iso2_codes_list

# There are some countries for which the converter could not find a country code. 
# We will drop these countries.
geo_df = geo_df.drop(geo_df.loc[geo_df['iso2_code'] == 'NULL'].index)
# Out:
# Dhekelia Sovereign Base Area not found in regex
# US Naval Base Guantanamo Bay not found in regex
# Siachen Glacier not found in regex
# Baykonur Cosmodrome not found in regex
# Akrotiri Sovereign Base Area not found in regex
# Southern Patagonian Ice Field not found in regex
# Bir Tawil not found in regex
# Indian Ocean Territories not found in regex
# Coral Sea Islands not found in regex
# Spratly Islands not found in regex
# Clipperton Island not found in regex
# Ashmore and Cartier Islands not found in regex
# Bajo Nuevo Bank (Petrel Is.) not found in regex
# Serranilla Bank not found in regex
# Scarborough Reef not found in regex

# %%
# We want to drop the history and only get the data from the last day
d = datetime.today()-timedelta(days=1)
date_yesterday = d.strftime("%Y-%m-%d")

# Preparing the data
covid_df = covid_df[covid_df['date'] == date_yesterday]

# Merge the two dataframes
merged_df = pd.merge(left=geo_df, right=covid_df, how='left', left_on='iso2_code', right_on='code')

# Delete some columns that we won't use
df = merged_df.drop(['day', 'month', 'year', 'country_y', 'code'], axis=1)

#Create the indicator values
df['case_growth_rate'] = round(df['cases']/df['cases_cum'], 2)
df['case_growth_rate'].fillna(0, inplace=True) 
df.head(3)
# Out:
#    country_x country_code                                           geometry  \
# 0  Indonesia          IDN  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1   Malaysia          MYS  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2      Chile          CHL  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
#
#   iso2_code date  cases  deaths  population continent  cases_cum  deaths_cum  \
# 0        ID  NaN    NaN     NaN         NaN       NaN        NaN         NaN
# 1        MY  NaN    NaN     NaN         NaN       NaN        NaN         NaN
# 2        CL  NaN    NaN     NaN         NaN       NaN        NaN         NaN
#
#    case_growth_rate
# 0               0.0
# 1               0.0
# 2               0.0

# %% [markdown]
# # Step #4 Print a Colorized Worldmap

# %%
# Print the map
# Set the range for the choropleth
title = 'Daily COVID-19 Growth Rates'
col = 'case_growth_rate'
source = 'Source: relataly.com \nGrowth Rate = New cases / All previous cases'
vmin = df[col].min()
vmax = df[col].max()
cmap = 'viridis'

# Create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(20, 8))

# Remove the axis
ax.axis('off')
df.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap)

# Add a title
ax.set_title(title, fontdict={'fontsize': '25', 'fontweight': '3'})

# Create an annotation for the data source
ax.annotate(source, xy=(0.1, .08), xycoords='figure fraction', horizontalalignment='left', 
            verticalalignment='bottom', fontsize=10)
            
# Create colorbar as a legend
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)

# Empty array for the data range
sm._A = []

# Add the colorbar to the figure
cbaxes = fig.add_axes([0.15, 0.25, 0.01, 0.4])
cbar = fig.colorbar(sm, cax=cbaxes)

# %%
# Safe the map to a png
fig.savefig('map_export.png', dpi=300)

# %% [markdown]
# # Step #6 Print a Map of Africa with Growth Rate per Day

# %%
# The map shows that many african countries are currently reporting increasing case numbers
# Next we create a new df based on a filter for african countries
africa_country_list = ['ZM', 'BF', 'TZ', 'EG', 'UG', 'TN', 'TG', 'SZ', 'SD', 
                       'EH', 'SS', 'ZW', 'ZA', 'SO', 'SL', 'SC', 'SN', 'ST', 
                       'SH', 'RW', 'RE', 'GW', 'NG', 'NE', 'NA', 'MZ', 'MA', 
                       'MU', 'MR', 'ML', 'MW', 'MG', 'LY', 'LR', 'LS', 'KE', 
                       'CI', 'GN', 'GH', 'GM', 'GA', 'DJ', 'ER', 'ET', 'GQ', 
                       'BJ', 'CD', 'CG', 'YT', 'KM', 'TD', 'CF', 'CV', 'CM', 
                       'BI', 'BW', 'AO', 'DZ']
africa_map_df = df[df['iso2_code'].isin(africa_country_list)]

# Plot the map for Africa
title = 'COVID-19 Growth Rate per Day in Africa'
col = 'case_growth_rate'
source = 'Source: relataly.com \nGrowth Rate = New cases / All previous cases'
vmin = df[col].min()
vmax = df[col].max()
fig, ax = plt.subplots(1, figsize=(20, 9))
ax.axis('off')
africa_map_df.plot(column=col, ax=ax, edgecolor='0.8', linewidth=1, cmap=cmap)
ax.set_title(title, fontdict={'fontsize': '25', 'fontweight': '3'})
ax.annotate(source, xy=(0.24, .08), xycoords='figure fraction',
            horizontalalignment='left',
            verticalalignment='bottom', fontsize=10)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
cbaxes = fig.add_axes([0.35, 0.25, 0.01, 0.5])
cbar = fig.colorbar(sm, cax=cbaxes)

# %%
africa_map_df
# Out:
#                             country_x country_code  \
# 12                           Ethiopia          ETH
# 13                        South Sudan          SDS
# 14                            Somalia          SOM
# 15                              Kenya          KEN
# 16                             Malawi          MWI
# 17        United Republic of Tanzania          TZA
# 19                         Somaliland          SOL
# 25                            Morocco          MAR
# 26                     Western Sahara          SAH
# 29              Republic of the Congo          COG
# 30   Democratic Republic of the Congo          COD
# 34                            Namibia          NAM
# 35                       South Africa          ZAF
# 70                              Libya          LBY
# 71                            Tunisia          TUN
# 79                             Zambia          ZMB
# 80                       Sierra Leone          SLE
# 81                             Guinea          GIN
# 82                            Liberia          LBR
# 83           Central African Republic          CAF
# 84                              Sudan          SDN
# 85                           Djibouti          DJI
# 86                            Eritrea          ERI
# 94                        Ivory Coast          CIV
# 96                               Mali          MLI
# 97                            Senegal          SEN
# 98                            Nigeria          NGA
# 99                              Benin          BEN
# 100                            Angola          AGO
# 105                          Botswana          BWA
# 106                          Zimbabwe          ZWE
# 113                              Chad          TCD
# 120                           Algeria          DZA
# 121                        Mozambique          MOZ
# 122                          eSwatini          SWZ
# 123                           Burundi          BDI
# 124                            Rwanda          RWA
# 131                            Uganda          UGA
# 143                           Lesotho          LSO
# 144                          Cameroon          CMR
# 145                             Gabon          GAB
# 146                             Niger          NER
# 147                      Burkina Faso          BFA
# 148                              Togo          TGO
# 149                             Ghana          GHA
# 150                     Guinea-Bissau          GNB
# 159                             Egypt          EGY
# 161                        Mauritania          MRT
# 162                 Equatorial Guinea          GNQ
# 163                            Gambia          GMB
# 173                        Madagascar          MDG
# 187                        Seychelles          SYC
# 209                      Saint Helena          SHN
# 210                         Mauritius          MUS
# 211                           Comoros          COM
# 212             São Tomé and Principe          STP
# 213                        Cabo Verde          CPV
#
#                                               geometry iso2_code date  cases  \
# 12   POLYGON ((34.07070 9.45459, 34.06689 9.53118, ...        ET  NaN    NaN
# 13   POLYGON ((35.92084 4.61933, 35.85654 4.61960, ...        SS  NaN    NaN
# 14   POLYGON ((46.46696 6.53829, 46.48805 6.55864, ...        SO  NaN    NaN
# 15   MULTIPOLYGON (((35.70585 4.61945, 35.70594 4.6...        KE  NaN    NaN
# 16   MULTIPOLYGON (((34.96461 -11.57356, 34.65125 -...        MW  NaN    NaN
# 17   MULTIPOLYGON (((32.92086 -9.40790, 32.90546 -9...        TZ  NaN    NaN
# 19   POLYGON ((48.93911 11.24913, 48.93911 11.13674...        SO  NaN    NaN
# 25   POLYGON ((-8.81703 27.66146, -8.81845 27.65940...        MA  NaN    NaN
# 26   POLYGON ((-8.81703 27.66146, -8.81654 27.66147...        EH  NaN    NaN
# 29   POLYGON ((18.62639 3.47687, 18.63455 3.44922, ...        CG  NaN    NaN
# 30   MULTIPOLYGON (((18.62639 3.47687, 18.59300 3.7...        CD  NaN    NaN
# 34   POLYGON ((16.48707 -28.57293, 16.46852 -28.585...        NA  NaN    NaN
# 35   MULTIPOLYGON (((19.98145 -24.75249, 19.98641 -...        ZA  NaN    NaN
# 70   POLYGON ((11.50511 33.18123, 11.52589 33.17695...        LY  NaN    NaN
# 71   MULTIPOLYGON (((11.50511 33.18123, 11.50605 33...        TN  NaN    NaN
# 79   POLYGON ((32.92086 -9.40790, 32.92303 -9.46629...        ZM  NaN    NaN
# 80   MULTIPOLYGON (((-10.28224 8.48463, -10.28291 8...        SL  NaN    NaN
# 81   POLYGON ((-13.30110 9.04149, -13.31237 9.04833...        GN  NaN    NaN
# 82   POLYGON ((-11.47619 6.91942, -11.44449 6.93394...        LR  NaN    NaN
# 83   POLYGON ((22.86106 10.91915, 22.86323 10.89182...        CF  NaN    NaN
# 84   MULTIPOLYGON (((22.86106 10.91915, 22.90023 11...        SD  NaN    NaN
# 85   POLYGON ((43.24073 11.48786, 43.18881 11.40776...        DJ  NaN    NaN
# 86   MULTIPOLYGON (((43.11769 12.70791, 42.90036 12...        ER  NaN    NaN
# 94   MULTIPOLYGON (((-7.98966 10.16199, -7.97090 10...        CI  NaN    NaN
# 96   POLYGON ((-12.26413 14.77494, -12.24679 14.767...        ML  NaN    NaN
# 97   POLYGON ((-12.26413 14.77494, -12.25651 14.745...        SN  NaN    NaN
# 98   MULTIPOLYGON (((3.59640 11.69577, 3.64777 11.7...        NG  NaN    NaN
# 99   POLYGON ((3.59640 11.69577, 3.57439 11.67304, ...        BJ  NaN    NaN
# 100  MULTIPOLYGON (((13.07370 -4.63532, 13.06533 -4...        AO  NaN    NaN
# 105  POLYGON ((25.25978 -17.79411, 25.21937 -17.879...        BW  NaN    NaN
# 106  POLYGON ((25.25978 -17.79411, 25.26671 -17.800...        ZW  NaN    NaN
# 113  POLYGON ((14.06491 13.07799, 13.83611 13.39104...        TD  NaN    NaN
# 120  POLYGON ((-4.82161 24.99506, -4.99519 25.10209...        DZ  NaN    NaN
# 121  MULTIPOLYGON (((32.11388 -26.84001, 32.11740 -...        MZ  NaN    NaN
# 122  POLYGON ((31.94924 -25.95810, 31.97529 -25.980...        SZ  NaN    NaN
# 123  POLYGON ((30.55460 -2.40063, 30.52148 -2.44228...        BI  NaN    NaN
# 124  POLYGON ((29.01537 -2.72071, 29.00012 -2.70366...        RW  NaN    NaN
# 131  POLYGON ((30.47179 -1.06684, 30.46083 -1.06343...        UG  NaN    NaN
# 143  POLYGON ((28.98085 -28.90904, 28.99542 -28.908...        LS  NaN    NaN
# 144  POLYGON ((11.32208 2.16576, 11.02298 2.16571, ...        CM  NaN    NaN
# 145  MULTIPOLYGON (((13.29457 2.16106, 13.29488 2.1...        GA  NaN    NaN
# 146  POLYGON ((3.59640 11.69577, 3.58937 11.70151, ...        NE  NaN    NaN
# 147  POLYGON ((2.39017 11.89654, 2.35410 11.79985, ...        BF  NaN    NaN
# 148  POLYGON ((-0.16611 11.13498, -0.11506 11.12466...        TG  NaN    NaN
# 149  POLYGON ((-0.16611 11.13498, -0.15867 11.11844...        GH  NaN    NaN
# 150  MULTIPOLYGON (((-13.72828 12.67339, -13.73631 ...        GW  NaN    NaN
# 159  MULTIPOLYGON (((34.24835 31.21145, 34.25861 31...        EG  NaN    NaN
# 161  MULTIPOLYGON (((-8.68239 27.28542, -8.48441 27...        MR  NaN    NaN
# 162  MULTIPOLYGON (((9.79957 2.34174, 9.81106 2.324...        GQ  NaN    NaN
# 163  POLYGON ((-16.75365 13.06501, -16.76887 13.077...        GM  NaN    NaN
# 173  MULTIPOLYGON (((44.25473 -20.37607, 44.25131 -...        MG  NaN    NaN
# 187  MULTIPOLYGON (((46.50978 -9.71998, 46.50758 -9...        SC  NaN    NaN
# 209  MULTIPOLYGON (((-9.92638 -40.34881, -9.90636 -...        SH  NaN    NaN
# 210  MULTIPOLYGON (((57.79575 -20.22275, 57.79396 -...        MU  NaN    NaN
# 211  MULTIPOLYGON (((43.78875 -12.30804, 43.79705 -...        KM  NaN    NaN
# 212  MULTIPOLYGON (((6.68141 0.40713, 6.70387 0.391...        ST  NaN    NaN
# 213  MULTIPOLYGON (((-24.70434 14.90082, -24.69310 ...        CV  NaN    NaN
#
#      deaths  population continent  cases_cum  deaths_cum  case_growth_rate
# 12      NaN         NaN       NaN        NaN         NaN               0.0
# 13      NaN         NaN       NaN        NaN         NaN               0.0
# 14      NaN         NaN       NaN        NaN         NaN               0.0
# 15      NaN         NaN       NaN        NaN         NaN               0.0
# 16      NaN         NaN       NaN        NaN         NaN               0.0
# 17      NaN         NaN       NaN        NaN         NaN               0.0
# 19      NaN         NaN       NaN        NaN         NaN               0.0
# 25      NaN         NaN       NaN        NaN         NaN               0.0
# 26      NaN         NaN       NaN        NaN         NaN               0.0
# 29      NaN         NaN       NaN        NaN         NaN               0.0
# 30      NaN         NaN       NaN        NaN         NaN               0.0
# 34      NaN         NaN       NaN        NaN         NaN               0.0
# 35      NaN         NaN       NaN        NaN         NaN               0.0
# 70      NaN         NaN       NaN        NaN         NaN               0.0
# 71      NaN         NaN       NaN        NaN         NaN               0.0
# 79      NaN         NaN       NaN        NaN         NaN               0.0
# 80      NaN         NaN       NaN        NaN         NaN               0.0
# 81      NaN         NaN       NaN        NaN         NaN               0.0
# 82      NaN         NaN       NaN        NaN         NaN               0.0
# 83      NaN         NaN       NaN        NaN         NaN               0.0
# 84      NaN         NaN       NaN        NaN         NaN               0.0
# 85      NaN         NaN       NaN        NaN         NaN               0.0
# 86      NaN         NaN       NaN        NaN         NaN               0.0
# 94      NaN         NaN       NaN        NaN         NaN               0.0
# 96      NaN         NaN       NaN        NaN         NaN               0.0
# 97      NaN         NaN       NaN        NaN         NaN               0.0
# 98      NaN         NaN       NaN        NaN         NaN               0.0
# 99      NaN         NaN       NaN        NaN         NaN               0.0
# 100     NaN         NaN       NaN        NaN         NaN               0.0
# 105     NaN         NaN       NaN        NaN         NaN               0.0
# 106     NaN         NaN       NaN        NaN         NaN               0.0
# 113     NaN         NaN       NaN        NaN         NaN               0.0
# 120     NaN         NaN       NaN        NaN         NaN               0.0
# 121     NaN         NaN       NaN        NaN         NaN               0.0
# 122     NaN         NaN       NaN        NaN         NaN               0.0
# 123     NaN         NaN       NaN        NaN         NaN               0.0
# 124     NaN         NaN       NaN        NaN         NaN               0.0
# 131     NaN         NaN       NaN        NaN         NaN               0.0
# 143     NaN         NaN       NaN        NaN         NaN               0.0
# 144     NaN         NaN       NaN        NaN         NaN               0.0
# 145     NaN         NaN       NaN        NaN         NaN               0.0
# 146     NaN         NaN       NaN        NaN         NaN               0.0
# 147     NaN         NaN       NaN        NaN         NaN               0.0
# 148     NaN         NaN       NaN        NaN         NaN               0.0
# 149     NaN         NaN       NaN        NaN         NaN               0.0
# 150     NaN         NaN       NaN        NaN         NaN               0.0
# 159     NaN         NaN       NaN        NaN         NaN               0.0
# 161     NaN         NaN       NaN        NaN         NaN               0.0
# 162     NaN         NaN       NaN        NaN         NaN               0.0
# 163     NaN         NaN       NaN        NaN         NaN               0.0
# 173     NaN         NaN       NaN        NaN         NaN               0.0
# 187     NaN         NaN       NaN        NaN         NaN               0.0
# 209     NaN         NaN       NaN        NaN         NaN               0.0
# 210     NaN         NaN       NaN        NaN         NaN               0.0
# 211     NaN         NaN       NaN        NaN         NaN               0.0
# 212     NaN         NaN       NaN        NaN         NaN               0.0
# 213     NaN         NaN       NaN        NaN         NaN               0.0

# %% [markdown]
# # Step #7 Print a Color-Map of Africa that shows Total COVID-19 Cases per Country

# %%
# Insert cases per population
# Alternative: africa_map_df2['cases_population'] = round(africa_map_df['cases_cum'] / africa_map_df['population'] * 100)
africa_map_df2 = africa_map_df.copy()

# Remove NAs
africa_map_df2.loc[: , 'cases_cum'].fillna(0, inplace=True)
# Show the data
africa_map_df2.head()

# Plot the map
title = 'Total COVID-19 Cases on the African Continent'
col = 'cases_cum'
source = 'Source: relataly.com '
vmin = africa_map_df2[col].min()
vmax = africa_map_df2[col].max()
fig, ax = plt.subplots(1, figsize=(20, 9))
ax.axis('off')
africa_map_df2.plot(column=col, ax=ax, edgecolor='1', linewidth=1, cmap=cmap)
ax.set_title(title, fontdict={'fontsize': '25', 'fontweight' : '3'})
ax.annotate(
    source, xy=(0.24, .08), xycoords='figure fraction', horizontalalignment='left', 
    verticalalignment='bottom', fontsize=10)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
cbaxes = fig.add_axes([0.35, 0.25, 0.01, 0.5])
cbar = fig.colorbar(sm, cax=cbaxes)

# %% [markdown]
# # Step #7 Print a Color-Map of Africa that shows Total COVID-19 Cases per Country

# %%
#Filter country codes
eu_country_list = ('IM', 'JE', 'GG', 'GB', 'MK', 'UA', 'TR', 'CH', 'SE', 'SJ', 
                   'ES', 'SI', 'SK', 'RS', 'SM', 'RO', 'PT', 'PL', 'NO', 'NL', 
                   'ME', 'MD', 'MC', 'MT', 'LU', 'LT', 'LI', 'LV', 'IT', 'IE', 
                   'IS', 'HU', 'VA', 'GR', 'GI', 'DE', 'GE', 'FR', 'AX', 'FI', 
                   'FO', 'EE', 'DK', 'CZ', 'CY', 'HR', 'BY', 'BG', 'BA', 'BE', 
                   'AM', 'AT', 'AZ', 'AD', 'AL')
eu_map = df[df['iso2_code'].isin(eu_country_list)]

# %%
#Calculate and insert cases per population
eu_map_df = eu_map.copy()
eu_map_df.insert(1, 'cases_population', round(eu_map_df['cases_cum'] / eu_map_df['population']*100, 5), True)
eu_map_df.loc[:, 'cases_population'].fillna(0, inplace=True)

# %%
# set the range for the choropleth
title = 'Total COVID-19 Cases in the EU'
col = 'cases_cum'
source = 'Source: relataly.com'
vmin = eu_map_df[col].min()
vmax = eu_map_df[col].max()
fig, ax = plt.subplots(1, figsize=(24, 8))

eu_map_df.plot(column=col, cmap=cmap, ax=ax, edgecolor='1', linewidth=1)
ax.set_title(title, fontdict={'fontsize': '25', 'fontweight':'3'})
ax.annotate(
    source, xy=(0.3, .08), xycoords='figure fraction', 
    horizontalalignment='left', verticalalignment='bottom', fontsize=10)
sm = plt.cm.ScalarMappable(norm=plt.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
# empty array for the data range
sm._A = []
cbar = fig.colorbar(sm)
